# %%
#|default_exp app

# %%
#|export
from fastai.vision.all import *
import gradio as gr

def is_cat(x): return x[0].isupper()

# %%
im=PILImage.create('dog.jpeg')
im.thumbnail((192,192))
im
# Out:
# PILImage mode=RGB size=192x144

# %%
#|export
learn=load_learner('model.pkl')

# %%
learn.predict(im)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('False', TensorImage(0), TensorImage([9.9999e-01, 8.4530e-06]))

# %%
#|export
categories={'Dog','Cat'}
def classify_image(img):
    pred,idx,probs = learn.predict(img)
    return dict (zip(categories, map (float,probs)))

# %%
classify_image(im)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# {'Cat': 0.9999915361404419, 'Dog': 8.452951078652404e-06}

# %%
#|export
image = gr.inputs.Image(shape=(192,192))
label = gr.outputs.Label()
examples = ['dog.jpeg']
intf = gr.Interface(fn=classify_image, inputs=image, outputs=label, examples=examples)
intf.launch(inline=False)
# Out:
# /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages/gradio/inputs.py:257: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages/gradio/outputs.py:197: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   warnings.warn(
# /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.

# %%
m=learn.model

# %%
ps=list(m.parameters())

# %%
ps[1]
# Out:
# Parameter containing:
# tensor([ 2.3354e-01,  2.6572e-01, -5.1096e-08,  5.1890e-01,  3.4404e-09,
#          2.2505e-01,  4.2238e-01,  1.3153e-07,  2.5062e-01,  1.5152e-06,
#          3.1717e-01,  2.5101e-01,  3.7763e-01,  1.0862e-05,  2.7484e-01,
#          2.3678e-01,  2.4192e-01,  3.9597e-01,  4.7087e-01,  2.9040e-01,
#          2.7101e-01,  2.7815e-01,  2.9033e-01,  2.0787e-01,  2.5954e-01,
#          2.7993e-01,  2.9236e-01,  3.1566e-01,  3.8785e-01,  3.0191e-01,
#          2.6638e-01,  2.1039e-01,  2.8616e-01,  3.3030e-01,  4.2668e-01,
#          3.7317e-01,  7.4804e-08,  1.9048e-01,  1.4740e-08,  2.2501e-01,
#          1.8082e-01,  2.4883e-01,  2.7247e-01,  2.5912e-01,  2.9463e-01,
#          2.9890e-01,  2.2480e-01,  2.6406e-01,  2.2001e-08,  2.6558e-01,
#          2.2037e-01,  2.8304e-01,  3.2963e-01,  2.2843e-01,  3.6554e-01,
#          2.1269e-01,  2.3919e-01,  2.5082e-01,  5.2501e-01,  2.4820e-01,
#          2.9392e-01,  2.5831e-01,  4.8124e-01,  2.6435e-01],
#        requires_grad=True)

# %%
# !pip install nbdev
# Out:
# Collecting nbdev
#   Using cached nbdev-2.3.12-py3-none-any.whl (64 kB)
# Collecting watchdog
#   Downloading watchdog-3.0.0-cp310-cp310-macosx_11_0_arm64.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: fastcore>=1.5.27 in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from nbdev) (1.5.29)
# Collecting execnb>=0.1.4
#   Using cached execnb-0.1.5-py3-none-any.whl (13 kB)
# Collecting ghapi>=1.0.3
#   Using cached ghapi-1.0.3-py3-none-any.whl (58 kB)
# Requirement already satisfied: asttokens in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from nbdev) (2.2.1)
# Collecting astunparse
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: PyYAML in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from nbdev) (6.0)
# Requirement already satisfied: ipython in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from execnb>=0.1.4->nbdev) (8.12.0)
# Requirement already satisfied: pip in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from fastcore>=1.5.27->nbdev) (22.3.1)
# Requirement already satisfied: packaging in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from fastcore>=1.5.27->nbdev) (23.1)
# Requirement already satisfied: six in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from asttokens->nbdev) (1.16.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from astunparse->nbdev) (0.37.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (3.0.38)
# Requirement already satisfied: appnope in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (0.1.3)
# Requirement already satisfied: pickleshare in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (0.7.5)
# Requirement already satisfied: stack-data in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (0.18.2)
# Requirement already satisfied: matplotlib-inline in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (0.1.6)
# Requirement already satisfied: backcall in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (2.15.0)
# Requirement already satisfied: pexpect>4.3 in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (4.8.0)
# Requirement already satisfied: decorator in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (5.1.1)
# Requirement already satisfied: traitlets>=5 in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from ipython->execnb>=0.1.4->nbdev) (5.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython->execnb>=0.1.4->nbdev) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from pexpect>4.3->ipython->execnb>=0.1.4->nbdev) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython->execnb>=0.1.4->nbdev) (0.2.6)
# Requirement already satisfied: pure-eval in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/hemanththaluru/miniconda3/lib/python3.10/site-packages (from stack-data->ipython->execnb>=0.1.4->nbdev) (1.2.0)
# Installing collected packages: watchdog, astunparse, ghapi, execnb, nbdev
# Successfully installed astunparse-1.6.3 execnb-0.1.5 ghapi-1.0.3 nbdev-2.3.12 watchdog-3.0.0

# %%
import nbdev
nbdev.export.nb_export('app2.ipynb', 'andapp')
print('Export successful')
# Out:
# Export successful
